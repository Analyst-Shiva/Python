# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns,sklearn

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# 1.Entire 1st row is box plot, horizontal, violin plot

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 15))

sns.boxplot(x='total_bill', data=tips, ax=axes[0, 0])
sns.violinplot(x='total_bill', data=tips, ax=axes[0, 1])
sns.scatterplot(x='total_bill', y='tip', data=tips, ax=axes[2, 1])

tips['day'].value_counts().plot.pie(ax=axes[2, 0], autopct='%1.1f%%', startangle=90)
axes[2, 0].set_ylabel('')

plt.show()

# %%
#2.Second row 1st coloumn is histogram
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.boxplot(x='total_bill', data=tips, ax=axes[0])
sns.boxplot(y='total_bill', data=tips, ax=axes[1])
sns.violinplot(x='total_bill', data=tips, ax=axes[2])

plt.show()

# %%
#3.Second row 2nd coloumn density plot with mean, median and mode, threshold lines, =1,-1 std

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.kdeplot(x='total_bill', data=tips, ax=axes[0])
axes[0].axvline(tips['total_bill'].mean(), color='red', ls='dashed', label='Mean')
axes[0].axvline(tips['total_bill'].median(), color='green', ls='dashed', label='Median')
axes[0].legend()

sns.kdeplot(x='total_bill', data=tips, ax=axes[1])
std_dev = tips['total_bill'].std()
axes[1].axvline(tips['total_bill'].mean() + std_dev, color='red', ls='dashed', label='+1 Std')
axes[1].axvline(tips['total_bill'].mean() - std_dev, color='red', ls='dashed', label='-1 Std')
axes[1].axvline(tips['total_bill'].mode().values[0], color='blue', ls='dashed', label='Mode')
axes[1].legend()

plt.show()

# %%
#4.Second row 3rd column schatterd plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

sns.kdeplot(x='total_bill', data=tips, ax=axes[0, 0])
axes[0, 0].axvline(tips['total_bill'].mean(), color='red', ls='dashed', label='Mean')
axes[0, 0].axvline(tips['total_bill'].median(), color='green', ls='dashed', label='Median')
axes[0, 0].legend()

sns.kdeplot(x='total_bill', data=tips, ax=axes[0, 1])
std_dev = tips['total_bill'].std()
axes[0, 1].axvline(tips['total_bill'].mean() + std_dev, color='red', ls='dashed', label='+1 Std')
axes[0, 1].axvline(tips['total_bill'].mean() - std_dev, color='red', ls='dashed', label='-1 Std')
axes[0, 1].legend()

sns.scatterplot(x='total_bill', y='tip', data=tips, ax=axes[1, 2])

plt.show()

# %%
#5.Third row - different plots , categroical coloumn - pie plot, 1st coloumn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

sns.kdeplot(x='total_bill', data=tips, ax=axes[0])
axes[0].axvline(tips['total_bill'].mean(), color='red', ls='dashed', label='Mean')
axes[0].axvline(tips['total_bill'].median(), color='green', ls='dashed', label='Median')
axes[0].legend()

# Other plots...

tip_size_counts = tips['size'].value_counts()
axes[2].pie(tip_size_counts, labels=tip_size_counts.index, autopct='%1.1f%%', startangle=90)
axes[2].set_aspect('equal')

plt.show()

# %%
#6.Third row 2nd coloumn- count plot, text on the bar on the count bar

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

sns.kdeplot(x='total_bill', data=tips, ax=axes[0])
axes[0].axvline(tips['total_bill'].mean(), color='red', ls='dashed', label='Mean')
axes[0].axvline(tips['total_bill'].median(), color='green', ls='dashed', label='Median')
axes[0].legend()

sns.countplot(x='day', data=tips, ax=axes[2])
for p in axes[2].patches:
    axes[2].annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center', xytext=(0, 10), textcoords='offset points')

tip_size_counts = tips['size'].value_counts()
axes[2].pie(tip_size_counts, labels=tip_size_counts.index, autopct='%1.1f%%', startangle=90)
axes[2].set_aspect('equal')

plt.show()

# %%
#8.Third 3rd coloumn - any visualization like butterfly plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

sns.kdeplot(x='total_bill', data=tips, ax=axes[0])
axes[0].axvline(tips['total_bill'].mean(), color='red', ls='dashed', label='Mean')
axes[0].axvline(tips['total_bill'].median(), color='green', ls='dashed', label='Median')
axes[0].legend()

sns.countplot(x='day', data=tips, ax=axes[2])
for p in axes[2].patches:
    axes[2].annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center', xytext=(0, 10), textcoords='offset points')

sns.violinplot(x='sex', y='total_bill', data=tips, ax=axes[2])

plt.show()

# %%
#9.subplots , using canvas and axis  
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

sns.kdeplot(x='total_bill', data=tips, ax=axes[0])
axes[0].axvline(tips['total_bill'].mean(), color='red', ls='dashed', label='Mean')
axes[0].axvline(tips['total_bill'].median(), color='green', ls='dashed', label='Median')
axes[0].legend()

sns.countplot(x='day', data=tips, ax=axes[2])
for p in axes[2].patches:
    axes[2].annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center', xytext=(0, 10), textcoords='offset points')

sns.violinplot(x='sex', y='total_bill', data=tips, ax=axes[2])

plt.show()

# %%
#10.Scatter using  seaborn plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()
