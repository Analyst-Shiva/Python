# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns, sklearn

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',
                delimiter = '|', index_col = 'user_id')

# %%
df
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
df.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
type(df.groupby(['occupation', 'gender'])['age'].mean())
# Out:
# pandas.core.series.Series

# %%
xx = df.groupby(['occupation', 'gender'])['age'].mean()

# %%
xx
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
xx['administrator']
# Out:
# gender
# F    40.638889
# M    37.162791
# Name: age, dtype: float64

# %%
xx['administrator']['F']
# Out:
# 40.638888888888886

# %%
xx.loc['administrator','F']
# Out:
# 40.638888888888886

# %%
df1 = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')

# %%
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df1.groupby(['continent', 'country']).agg(Beeravg=('beer_servings', 'mean'), BeerMedian=('beer_servings','median'))
# Out:
#                         Beeravg  BeerMedian
# continent country
# AF        Algeria            25          25
#           Angola            217         217
#           Benin              34          34
#           Botswana          173         173
#           Burkina Faso       25          25
# ...                         ...         ...
# SA        Paraguay          213         213
#           Peru              163         163
#           Suriname          128         128
#           Uruguay           115         115
#           Venezuela         333         333
#
# [170 rows x 2 columns]

# %%
x = df1.groupby(['continent', 'country']).agg(Beeravg=('beer_servings', 'mean'), BeerMedian=('beer_servings','median')).unstack()

# %%
x
# Out:
#           Beeravg                                                        \
# country   Algeria Angola Benin Botswana Burkina Faso Burundi Cabo Verde
# continent
# AF           25.0  217.0  34.0    173.0         25.0    88.0      144.0
# AS            NaN    NaN   NaN      NaN          NaN     NaN        NaN
# EU            NaN    NaN   NaN      NaN          NaN     NaN        NaN
# OC            NaN    NaN   NaN      NaN          NaN     NaN        NaN
# SA            NaN    NaN   NaN      NaN          NaN     NaN        NaN
#
#                                                    ... BeerMedian         \
# country   Cameroon Central African Republic  Chad  ...     Brazil  Chile
# continent                                          ...
# AF           147.0                     17.0  15.0  ...        NaN    NaN
# AS             NaN                      NaN   NaN  ...        NaN    NaN
# EU             NaN                      NaN   NaN  ...        NaN    NaN
# ...

# %%
x.loc['AF']
# Out:
#             country
# Beeravg     Algeria          25.0
#             Angola          217.0
#             Benin            34.0
#             Botswana        173.0
#             Burkina Faso     25.0
#                             ...
# BeerMedian  Paraguay          NaN
#             Peru              NaN
#             Suriname          NaN
#             Uruguay           NaN
#             Venezuela         NaN
# Name: AF, Length: 340, dtype: float64

# %%
x.loc['AF' , 'Beeravg']
# Out:
# country
# Algeria          25.0
# Angola          217.0
# Benin            34.0
# Botswana        173.0
# Burkina Faso     25.0
#                 ...
# Paraguay          NaN
# Peru              NaN
# Suriname          NaN
# Uruguay           NaN
# Venezuela         NaN
# Name: AF, Length: 170, dtype: float64

# %%
x.loc['AF' , 'Beeravg']['Algeria']
# Out:
# 25.0

# %%
data = pd.read_csv(r'C:\Users\HP PC\Downloads\loandata.csv')

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (480, 13)

# %%
data.describe(include = 'all').T
# Out:
#                   count unique        top freq      mean       std  min  \
# Loan_ID             480    480   LP001608    1       NaN       NaN  NaN
# Gender              480      2       Male  394       NaN       NaN  NaN
# Married             480      2        Yes  311       NaN       NaN  NaN
# Dependents          480      4          0  274       NaN       NaN  NaN
# Education           480      2   Graduate  383       NaN       NaN  NaN
# Self_Employed       480      2         No  414       NaN       NaN  NaN
# ApplicantIncome     480    NaN        NaN  NaN   5364.23   5668.25  150
# CoapplicantIncome   480    NaN        NaN  NaN   1581.09   2617.69    0
# LoanAmount          480    NaN        NaN  NaN   144.735   80.5082    9
# Loan_Amount_Term    480    NaN        NaN  NaN    342.05   65.2124   36
# Credit_History      480    NaN        NaN  NaN  0.854167  0.353307    0
# Property_Area       480      3  Semiurban  191       NaN       NaN  NaN
# ...

# %%
# dir(pd.MultiIndex)

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001722    Male     Yes          0  Graduate            No
# 3    LP002603  Female      No          0  Graduate            No
# 5    LP001259    Male     Yes          1  Graduate           Yes
# 6    LP002345    Male     Yes          0  Graduate            No
# 8    LP001030    Male     Yes          2  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 607  LP001637    Male     Yes          1  Graduate            No
# 608  LP002422    Male      No          1  Graduate            No
# 609  LP001640    Male     Yes          0  Graduate           Yes
# 610  LP001536    Male     Yes         3+  Graduate            No
# 613  LP002317    Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
pd.MultiIndex.from_frame(data)
# Out:
# MultiIndex([('LP001722',   'Male', 'Yes',  '0',     'Graduate',  'No', ...),
#             ('LP002603', 'Female',  'No',  '0',     'Graduate',  'No', ...),
#             ('LP001259',   'Male', 'Yes',  '1',     'Graduate', 'Yes', ...),
#             ('LP002345',   'Male', 'Yes',  '0',     'Graduate',  'No', ...),
#             ('LP001030',   'Male', 'Yes',  '2',     'Graduate',  'No', ...),
#             ('LP001267', 'Female', 'Yes',  '2',     'Graduate',  'No', ...),
#             ('LP001086',   'Male',  'No',  '0', 'Not Graduate',  'No', ...),
#             ('LP002287', 'Female',  'No',  '0',     'Graduate',  'No', ...),
#             ('LP001518',   'Male', 'Yes',  '1',     'Graduate',  'No', ...),
#             ('LP002342',   'Male', 'Yes',  '2',     'Graduate', 'Yes', ...),
#             ...
#             ('LP002731', 'Female',  'No',  '0', 'Not Graduate', 'Yes', ...),
#             ('LP002547',   'Male', 'Yes',  '1',     'Graduate',  'No', ...),
# ...

# %%
data.set_index('Loan_ID')
# Out:
#           Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001722    Male     Yes          0  Graduate            No              150
# LP002603  Female      No          0  Graduate            No              645
# LP001259    Male     Yes          1  Graduate           Yes             1000
# LP002345    Male     Yes          0  Graduate            No             1025
# LP001030    Male     Yes          2  Graduate            No             1299
# ...          ...     ...        ...       ...           ...              ...
# LP001637    Male     Yes          1  Graduate            No            33846
# LP002422    Male      No          1  Graduate            No            37719
# LP001640    Male     Yes          0  Graduate           Yes            39147
# LP001536    Male     Yes         3+  Graduate            No            39999
# LP002317    Male     Yes         3+  Graduate            No            81000
#
# ...

# %%
data.set_index(['Gender', 'Married'])
# Out:
#                  Loan_ID Dependents Education Self_Employed  ApplicantIncome  \
# Gender Married
# Male   Yes      LP001722          0  Graduate            No              150
# Female No       LP002603          0  Graduate            No              645
# Male   Yes      LP001259          1  Graduate           Yes             1000
#        Yes      LP002345          0  Graduate            No             1025
#        Yes      LP001030          2  Graduate            No             1299
# ...                  ...        ...       ...           ...              ...
#        Yes      LP001637          1  Graduate            No            33846
#        No       LP002422          1  Graduate            No            37719
#        Yes      LP001640          0  Graduate           Yes            39147
#        Yes      LP001536         3+  Graduate            No            39999
#        Yes      LP002317         3+  Graduate            No            81000
#
# ...

# %%
type(data.set_index(['Gender', 'Married']))
# Out:
# pandas.core.frame.DataFrame

# %%
xx = data.set_index(['Gender', 'Married'])

# %%
xx
# Out:
#                  Loan_ID Dependents Education Self_Employed  ApplicantIncome  \
# Gender Married
# Male   Yes      LP001722          0  Graduate            No              150
# Female No       LP002603          0  Graduate            No              645
# Male   Yes      LP001259          1  Graduate           Yes             1000
#        Yes      LP002345          0  Graduate            No             1025
#        Yes      LP001030          2  Graduate            No             1299
# ...                  ...        ...       ...           ...              ...
#        Yes      LP001637          1  Graduate            No            33846
#        No       LP002422          1  Graduate            No            37719
#        Yes      LP001640          0  Graduate           Yes            39147
#        Yes      LP001536         3+  Graduate            No            39999
#        Yes      LP002317         3+  Graduate            No            81000
#
# ...

# %%
type(xx)
# Out:
# pandas.core.frame.DataFrame

# %%
xx
# Out:
#                  Loan_ID Dependents Education Self_Employed  ApplicantIncome  \
# Gender Married
# Male   Yes      LP001722          0  Graduate            No              150
# Female No       LP002603          0  Graduate            No              645
# Male   Yes      LP001259          1  Graduate           Yes             1000
#        Yes      LP002345          0  Graduate            No             1025
#        Yes      LP001030          2  Graduate            No             1299
# ...                  ...        ...       ...           ...              ...
#        Yes      LP001637          1  Graduate            No            33846
#        No       LP002422          1  Graduate            No            37719
#        Yes      LP001640          0  Graduate           Yes            39147
#        Yes      LP001536         3+  Graduate            No            39999
#        Yes      LP002317         3+  Graduate            No            81000
#
# ...

# %%
xx.groupby(['Education', 'Self_Employed']).agg(ApplictIncomeMean = ('ApplicantIncome', 'mean'))
# Out:
#                             ApplictIncomeMean
# Education    Self_Employed
# Graduate     No                   5365.627273
#              Yes                  8056.679245
# Not Graduate No                   3455.750000
#              Yes                  6683.615385

# %%
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...
