# %%
import matplotlib.pyplot as plt, seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
help(sns.load_dataset)('iris')
# Out:
# Help on function load_dataset in module seaborn.utils:
#
# load_dataset(name, cache=True, data_home=None, **kws)
#     Load an example dataset from the online repository (requires internet).
#
#     This function provides quick access to a small number of example datasets
#     that are useful for documenting seaborn or generating reproducible examples
#     for bug reports. It is not necessary for normal usage.
#
#     Note that some of the datasets have a small amount of preprocessing applied
#     to define a proper ordering for categorical variables.
#
#     Use :func:`get_dataset_names` to see a list of available datasets.
#
#     Parameters
#     ----------
#     name : str
#         Name of the dataset (``{name}.csv`` on
#         https://github.com/mwaskom/seaborn-data).
#     cache : boolean, optional
#         If True, try to load from the local cache first, and save to the cache
#         if a download is required.
#     data_home : string, optional
# ...

# %%
df = (sns.load_dataset)('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# (None,
#         sepal_length  sepal_width  petal_length  petal_width
#  count    150.000000   150.000000    150.000000   150.000000
#  mean       5.843333     3.057333      3.758000     1.199333
#  std        0.828066     0.435866      1.765298     0.762238
#  min        4.300000     2.000000      1.000000     0.100000
#  25%        5.100000     2.800000      1.600000     0.300000
#  50%        5.800000     3.000000      4.350000     1.300000
#  75%        6.400000     3.300000      5.100000     1.800000
# ...

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df.describe(include= 'all').T
# Out:
#               count unique     top freq      mean       std  min  25%   50%  \
# sepal_length  150.0    NaN     NaN  NaN  5.843333  0.828066  4.3  5.1   5.8
# sepal_width   150.0    NaN     NaN  NaN  3.057333  0.435866  2.0  2.8   3.0
# petal_length  150.0    NaN     NaN  NaN     3.758  1.765298  1.0  1.6  4.35
# petal_width   150.0    NaN     NaN  NaN  1.199333  0.762238  0.1  0.3   1.3
# species         150      3  setosa   50       NaN       NaN  NaN  NaN   NaN
#
#               75%  max
# sepal_length  6.4  7.9
# sepal_width   3.3  4.4
# petal_length  5.1  6.9
# petal_width   1.8  2.5
# species       NaN  NaN

# %%
df['sepal_length'].plot()
# Out:
# <Axes: >

# %%
df['sepal_length'].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']== 'setosa']['sepal_length'].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']== 'virginica']['sepal_length'].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']== 'versicolor']['petal_length'].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df[df['species']== 'versicolor']['petal_length'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64>

# %%
df[df['species']== 'versicolor']['petal_length'].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64>

# %%
df[df['species']== 'versicolor']['petal_length'].mode
# Out:
# <bound method Series.mode of 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64>

# %%
df[df['species']== 'versicolor']['petal_length'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64>

# %%
df[df['species']== 'versicolor']['petal_length'].var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64>

# %%
print(df[df['species']== 'setosa']['sepal_length'].mean())
print(df[df['species']== 'setosa']['sepal_width'].mean())
# Out:
# 5.006
# 3.428

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.mean()
# Out:
# <ipython-input-45-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
df['species'].unique(), df['species'].nunique()
# Out:
# (array(['setosa', 'versicolor', 'virginica'], dtype=object), 3)

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
type(df['species'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df['species'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['species'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='species'>

# %%
df['species'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['species']== 'virginica']['petal_length'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['species']== 'versicolor']['petal_length'].plot(kind="bar")
# Out:
# <Axes: >

# %%
df[df['species']== 'versicolor']['petal_length'].plot(kind="pie")
# Out:
# <Axes: ylabel='petal_length'>

# %%
df[df['species']== 'versicolor']['petal_length'].plot(kind="line")
# Out:
# <Axes: >

# %%
df[df['species']== 'versicolor']['petal_length'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64>

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df[df['petal_length'] > 3.7580] ['species'].value_counts()
# Out:
# virginica     50
# versicolor    43
# Name: species, dtype: int64

# %%
df[df['petal_width'] > 3.7580] ['species'].value_counts()
# Out:
# Series([], Name: species, dtype: int64)

# %%
df[df['petal_length'] >= 3.7580] ['species'].value_counts()
# Out:
# virginica     50
# versicolor    43
# Name: species, dtype: int64

# %%
df.sort_values(by = ['sepal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by = ['sepal_length'], ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
df.sort_values(by = ['sepal_length'], ascending=True)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by = ['sepal_length', 'petal_length'], ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
df.sort_values(by=['sepal_length'], ascending=False, inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 131 to 13
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
#Savings Account: Primarily for saving money, earns interest, limited transactions, no overdraft.
#Current Account: For daily transactions, often used by businesses, minimal or no interest, more transactions allowed, may have overdraft facilities.

# %%
#savings account and checking accounts info needs to be done
